# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
data_dir = '../data/raw/UCF50/'

# %%
class_names = os.listdir(data_dir)

# %%
import os
import cv2
import numpy as np

def compute_dataset_statistics(data_dir, class_names):
    dic_class_distribution = {}
    median_frames_per_video = {}
    max_frames_per_video = {}
    min_frames_per_video = {}
    mode_frames_per_video = {}
    class_sizes = {}
    total_dataset_size = 0

    for class_name in class_names:
        class_input_path = os.path.join(data_dir, class_name)
        number_of_videos = len(os.listdir(class_input_path))
        dic_class_distribution[class_name] = number_of_videos
        frames_count = []
        class_size = 0
        
        for video_name in os.listdir(class_input_path):
            video_path = os.path.join(class_input_path, video_name)
            cap = cv2.VideoCapture(video_path)
            frame_count = 0
            
            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                frame_count += 1
            
            frames_count.append(frame_count)
            cap.release()
            
            # Compute the size of the video file
            video_size = os.path.getsize(video_path)
            class_size += video_size
            total_dataset_size += video_size
        
        median_frames_per_video[class_name] = np.median(frames_count)
        max_frames_per_video[class_name] = np.max(frames_count)
        min_frames_per_video[class_name] = np.min(frames_count)
        mode_frames_per_video[class_name] = np.bincount(frames_count).argmax()
        class_sizes[class_name] = class_size

    return {
        "class_distribution": dic_class_distribution,
        "median_frames_per_video": median_frames_per_video,
        "max_frames_per_video": max_frames_per_video,
        "min_frames_per_video": min_frames_per_video,
        "mode_frames_per_video": mode_frames_per_video,
        "class_sizes": class_sizes,
        "total_dataset_size": total_dataset_size
    }


statistics = compute_dataset_statistics(data_dir, class_names)

# %%
print("Class Distribution:", statistics["class_distribution"])
print("Median Frames per Video:", statistics["median_frames_per_video"])
print("Max Frames per Video:", statistics["max_frames_per_video"])
print("Min Frames per Video:", statistics["min_frames_per_video"])
print("Mode Frames per Video:", statistics["mode_frames_per_video"])
print("Class Sizes (in bytes):", statistics["class_sizes"])
print(f"Total Dataset Size: {statistics['total_dataset_size'] / (1024 * 1024 * 1024):.2f} GB")
# Out:
# Class Distribution: {'Mixing': 142, 'TennisSwing': 167, 'HorseRiding': 197, 'JumpRope': 148, 'JumpingJack': 123, 'BaseballPitch': 150, 'Rowing': 137, 'SkateBoarding': 120, 'WalkingWithDog': 123, 'Skijet': 100, 'Nunchucks': 150, 'Billiards': 150, 'PullUps': 120, 'Swing': 137, 'PoleVault': 160, 'GolfSwing': 142, 'Lunges': 141, 'PommelHorse': 123, 'BreastStroke': 101, 'PlayingPiano': 105, 'PlayingTabla': 124, 'Basketball': 137, 'VolleyballSpiking': 116, 'SoccerJuggling': 156, 'CleanAndJerk': 112, 'YoYo': 128, 'PushUps': 106, 'Kayaking': 157, 'HulaHoop': 125, 'JugglingBalls': 122, 'PlayingGuitar': 160, 'Fencing': 111, 'ThrowDiscus': 131, 'MilitaryParade': 127, 'RopeClimbing': 130, 'Biking': 145, 'Punch': 160, 'Drumming': 161, 'BenchPress': 160, 'Diving': 153, 'SalsaSpin': 133, 'PizzaTossing': 114, 'TaiChi': 100, 'HighJump': 123, 'JavelinThrow': 117, 'TrampolineJumping': 119, 'Skiing': 144, 'PlayingViolin': 100, 'HorseRace': 127, 'RockClimbingIndoor': 148}
# Median Frames per Video: {'Mixing': 113.0, 'TennisSwing': 143.0, 'HorseRiding': 201.0, 'JumpRope': 447.5, 'JumpingJack': 85.0, 'BaseballPitch': 99.0, 'Rowing': 304.0, 'SkateBoarding': 127.0, 'WalkingWithDog': 240.0, 'Skijet': 210.0, 'Nunchucks': 248.5, 'Billiards': 287.0, 'PullUps': 138.0, 'Swing': 151.0, 'PoleVault': 163.0, 'GolfSwing': 145.0, 'Lunges': 249.0, 'PommelHorse': 308.0, 'BreastStroke': 158.0, 'PlayingPiano': 218.0, 'PlayingTabla': 277.0, 'Basketball': 120.0, 'VolleyballSpiking': 104.0, 'SoccerJuggling': 251.0, 'CleanAndJerk': 193.5, 'YoYo': 182.0, 'PushUps': 77.0, 'Kayaking': 177.0, 'HulaHoop': 96.0, 'JugglingBalls': 250.5, 'PlayingGuitar': 250.0, 'Fencing': 130.0, 'ThrowDiscus': 93.0, 'MilitaryParade': 127.0, 'RopeClimbing': 161.5, 'Biking': 209.0, 'Punch': 300.0, 'Drumming': 300.0, 'BenchPress': 98.0, 'Diving': 161.0, 'SalsaSpin': 168.0, 'PizzaTossing': 120.0, 'TaiChi': 176.0, 'HighJump': 109.0, 'JavelinThrow': 95.0, 'TrampolineJumping': 201.0, 'Skiing': 203.5, 'PlayingViolin': 176.0, 'HorseRace': 271.0, 'RockClimbingIndoor': 400.0}
# Max Frames per Video: {'Mixing': 165, 'TennisSwing': 367, 'HorseRiding': 311, 'JumpRope': 623, 'JumpingJack': 138, 'BaseballPitch': 213, 'Rowing': 846, 'SkateBoarding': 369, 'WalkingWithDog': 240, 'Skijet': 418, 'Nunchucks': 385, 'Billiards': 592, 'PullUps': 261, 'Swing': 335, 'PoleVault': 480, 'GolfSwing': 641, 'Lunges': 298, 'PommelHorse': 669, 'BreastStroke': 418, 'PlayingPiano': 248, 'PlayingTabla': 396, 'Basketball': 492, 'VolleyballSpiking': 261, 'SoccerJuggling': 891, 'CleanAndJerk': 371, 'YoYo': 218, 'PushUps': 166, 'Kayaking': 499, 'HulaHoop': 221, 'JugglingBalls': 276, 'PlayingGuitar': 300, 'Fencing': 174, 'ThrowDiscus': 165, 'MilitaryParade': 168, 'RopeClimbing': 327, 'Biking': 598, 'Punch': 300, 'Drumming': 300, 'BenchPress': 312, 'Diving': 384, 'SalsaSpin': 333, 'PizzaTossing': 202, 'TaiChi': 267, 'HighJump': 232, 'JavelinThrow': 170, 'TrampolineJumping': 449, 'Skiing': 354, 'PlayingViolin': 509, 'HorseRace': 391, 'RockClimbingIndoor': 843}
# Min Frames per Video: {'Mixing': 61, 'TennisSwing': 62, 'HorseRiding': 32, 'JumpRope': 189, 'JumpingJack': 54, 'BaseballPitch': 47, 'Rowing': 113, 'SkateBoarding': 59, 'WalkingWithDog': 93, 'Skijet': 149, 'Nunchucks': 138, 'Billiards': 92, 'PullUps': 67, 'Swing': 51, 'PoleVault': 69, 'GolfSwing': 65, 'Lunges': 47, 'PommelHorse': 202, 'BreastStroke': 67, 'PlayingPiano': 201, 'PlayingTabla': 113, 'Basketball': 53, 'VolleyballSpiking': 53, 'SoccerJuggling': 82, 'CleanAndJerk': 67, 'YoYo': 136, 'PushUps': 29, 'Kayaking': 151, 'HulaHoop': 78, 'JugglingBalls': 191, 'PlayingGuitar': 200, 'Fencing': 94, 'ThrowDiscus': 55, 'MilitaryParade': 78, 'RopeClimbing': 72, 'Biking': 101, 'Punch': 48, 'Drumming': 111, 'BenchPress': 45, 'Diving': 60, 'SalsaSpin': 153, 'PizzaTossing': 36, 'TaiChi': 168, 'HighJump': 60, 'JavelinThrow': 48, 'TrampolineJumping': 106, 'Skiing': 85, 'PlayingViolin': 141, 'HorseRace': 78, 'RockClimbingIndoor': 149}
# Mode Frames per Video: {'Mixing': 101, 'TennisSwing': 122, 'HorseRiding': 240, 'JumpRope': 510, 'JumpingJack': 88, 'BaseballPitch': 104, 'Rowing': 168, 'SkateBoarding': 126, 'WalkingWithDog': 240, 'Skijet': 210, 'Nunchucks': 255, 'Billiards': 217, 'PullUps': 178, 'Swing': 126, 'PoleVault': 199, 'GolfSwing': 145, 'Lunges': 262, 'PommelHorse': 301, 'BreastStroke': 93, 'PlayingPiano': 225, 'PlayingTabla': 251, 'Basketball': 120, 'VolleyballSpiking': 101, 'SoccerJuggling': 301, 'CleanAndJerk': 146, 'YoYo': 178, 'PushUps': 84, 'Kayaking': 151, 'HulaHoop': 101, 'JugglingBalls': 253, 'PlayingGuitar': 250, 'Fencing': 125, 'ThrowDiscus': 71, 'MilitaryParade': 138, 'RopeClimbing': 151, 'Biking': 240, 'Punch': 300, 'Drumming': 300, 'BenchPress': 65, 'Diving': 158, 'SalsaSpin': 167, 'PizzaTossing': 120, 'TaiChi': 171, 'HighJump': 108, 'JavelinThrow': 51, 'TrampolineJumping': 201, 'Skiing': 300, 'PlayingViolin': 176, 'HorseRace': 308, 'RockClimbingIndoor': 167}
# Class Sizes (in bytes): {'Mixing': 47999837, 'TennisSwing': 52701090, 'HorseRiding': 90354556, 'JumpRope': 136717458, 'JumpingJack': 27441950, 'BaseballPitch': 38079386, 'Rowing': 120930958, 'SkateBoarding': 45315592, 'WalkingWithDog': 64850082, 'Skijet': 53399312, 'Nunchucks': 91385064, 'Billiards': 115873184, 'PullUps': 39241262, 'Swing': 69832986, 'PoleVault': 67465214, 'GolfSwing': 52957732, 'Lunges': 91971036, 'PommelHorse': 99965878, 'BreastStroke': 49646082, 'PlayingPiano': 41242936, 'PlayingTabla': 91711672, 'Basketball': 42771850, 'VolleyballSpiking': 29244242, 'SoccerJuggling': 101000710, 'CleanAndJerk': 59228390, 'YoYo': 65198002, 'PushUps': 23594480, 'Kayaking': 87107238, 'HulaHoop': 37122810, 'JugglingBalls': 77901930, 'PlayingGuitar': 105824052, 'Fencing': 43015646, 'ThrowDiscus': 38842172, 'MilitaryParade': 52020426, 'RopeClimbing': 57579650, 'Biking': 76889458, 'Punch': 126231752, 'Drumming': 130864230, 'BenchPress': 57664820, 'Diving': 62764150, 'SalsaSpin': 77409344, 'PizzaTossing': 39928688, 'TaiChi': 46705236, 'HighJump': 40883496, 'JavelinThrow': 34204004, 'TrampolineJumping': 58426250, 'Skiing': 74737390, 'PlayingViolin': 48315960, 'HorseRace': 77992304, 'RockClimbingIndoor': 135311866}
# Total Dataset Size: 3.16 GB

# %%
# Ensure the directory exists
output_dir = '../reports/plots'
os.makedirs(output_dir, exist_ok=True)

# Plotting Class Distribution
plt.figure(figsize=(12, 6))
plt.bar(statistics["class_distribution"].keys(), statistics["class_distribution"].values(), color='skyblue')
plt.xlabel('Class Names')
plt.ylabel('Number of Videos')
plt.title('Class Distribution')
plt.xticks(rotation=90)
plt.savefig(os.path.join(output_dir, 'class_distribution.png'))
plt.close()

# Plotting Median Frames per Video
plt.figure(figsize=(12, 6))
plt.bar(statistics["median_frames_per_video"].keys(), statistics["median_frames_per_video"].values(), color='lightgreen')
plt.xlabel('Class Names')
plt.ylabel('Median Frames per Video')
plt.title('Median Frames per Video per Class')
plt.xticks(rotation=90)
plt.savefig(os.path.join(output_dir, 'median_frames_per_video.png'))
plt.close()

# Plotting Class Sizes
plt.figure(figsize=(12, 6))
plt.bar(statistics["class_sizes"].keys(), [size / (1024 * 1024 * 1024) for size in statistics["class_sizes"].values()], color='lightcoral')
plt.xlabel('Class Names')
plt.ylabel('Size (GB)')
plt.title('Class Sizes')
plt.xticks(rotation=90)
plt.savefig(os.path.join(output_dir, 'class_sizes.png'))
plt.close()

# Plotting Max Frames per Video
plt.figure(figsize=(12, 6))
plt.bar(statistics["max_frames_per_video"].keys(), statistics["max_frames_per_video"].values(), color='lightblue')
plt.xlabel('Class Names')
plt.ylabel('Max Frames per Video')
plt.title('Max Frames per Video per Class')
plt.xticks(rotation=90)
plt.savefig(os.path.join(output_dir, 'max_frames_per_video.png'))
plt.close()

# Plotting Min Frames per Video
plt.figure(figsize=(12, 6))
plt.bar(statistics["min_frames_per_video"].keys(), statistics["min_frames_per_video"].values(), color='lightgreen')
plt.xlabel('Class Names')
plt.ylabel('Min Frames per Video')
plt.title('Min Frames per Video per Class')
plt.xticks(rotation=90)
plt.savefig(os.path.join(output_dir, 'min_frames_per_video.png'))
plt.close()

# Plotting Mode Frames per Video
plt.figure(figsize=(12, 6))
plt.bar(statistics["mode_frames_per_video"].keys(), statistics["mode_frames_per_video"].values(), color='lightcoral')
plt.xlabel('Class Names')
plt.ylabel('Mode Frames per Video')
plt.title('Mode Frames per Video per Class')
plt.xticks(rotation=90)
plt.savefig(os.path.join(output_dir, 'mode_frames_per_video.png'))
plt.close()
