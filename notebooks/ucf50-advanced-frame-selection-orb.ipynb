# %%
import os
import cv2
import numpy as np

# %%
def preprocess_frame(frame):
    
    # Apply filtering, smoothing, sharpening, and adjusting brightness and contrast
    blurred = cv2.GaussianBlur(frame, (5, 5), 0)
    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    sharpened = cv2.filter2D(blurred, -1, kernel)
    
    alpha = 1.1  # Contrast control
    beta = 15    # Brightness control
    adjusted = cv2.convertScaleAbs(sharpened, alpha=alpha, beta=beta)
    
    # Normalize the image
    normalized = cv2.normalize(adjusted, None, 0, 255, cv2.NORM_MINMAX)
    
    return normalized

# %%
def create_gif(frames, gif_path):
    with imageio.get_writer(gif_path, mode='I', duration=0.1) as writer:
        for frame in frames:
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            writer.append_data(rgb_frame)

def display_gif(gif_path):
    return Image(filename=gif_path)

def save_frames_as_avi(frames, output_path, fps=30):
    if not frames:
        print("No frames to save.")
        return
    
    height, width, layers = frames[0].shape
    size = (width, height)
    
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'XVID'), fps, size)
    
    for frame in frames:
        out.write(frame)
    
    out.release()
    print(f"Video saved as {output_path}")

# %%
def ucf50_preprocessing(data_dir, output_dir, class_names, number_of_frames, threshold=40):
    orb = cv2.ORB_create()
    for class_name in class_names:
        class_input_path = os.path.join(data_dir, class_name)
        output_class_path = os.path.join(output_dir, class_name)
        os.makedirs(output_class_path, exist_ok=True)
        
        for video_name in os.listdir(class_input_path):
            video_path = os.path.join(class_input_path, video_name)
            cap = cv2.VideoCapture(video_path)
            relevant_frames = []
            all_frames = []
            prev_descriptors = None
            total_frames = 0
            
            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                
                total_frames += 1
                all_frames.append(frame)
                processed_frame = preprocess_frame(frame)
                keypoints, descriptors = orb.detectAndCompute(processed_frame, None)
                
                if descriptors is not None and len(descriptors) > 0:
                    if prev_descriptors is None:
                        relevant_frames.append(frame)
                    else:
                        # Compute the distance between descriptors
                        bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
                        matches = bf.match(prev_descriptors, descriptors)
                        distances = [m.distance for m in matches]
                        avg_distance = np.mean(distances)
                        
                        if avg_distance > threshold:
                            relevant_frames.append(frame)
                    
                    prev_descriptors = descriptors
            
            cap.release()
            
            # Ensure minimum number of frames is at least 10
            if len(relevant_frames) < number_of_frames:
                print(f"Selected frames: {len(relevant_frames)}\n")
                needed_frames = number_of_frames - len(relevant_frames)
                relevant_frames.extend(all_frames[:needed_frames])
            
            print(f"Video: {video_name}")
            print(f"Total frames: {total_frames}")
            print(f"Selected frames: {len(relevant_frames)}\n")
            
            # Save the selected frames as an AVI video
            output_video_path = os.path.join(output_class_path, video_name)
            save_frames_as_avi(relevant_frames, output_video_path)

# %%
data_dir = '../data/raw/UCF50/'

# %%
output_dir = '../data/processed/ORB/'

# %%
class_names = os.listdir(data_dir)

# %%
class_names
# Out:
# ['Mixing',
#  'TennisSwing',
#  'HorseRiding',
#  'JumpRope',
#  'JumpingJack',
#  'BaseballPitch',
#  'Rowing',
#  'SkateBoarding',
#  'WalkingWithDog',
#  'Skijet',
#  'Nunchucks',
#  'Billiards',
#  'PullUps',
#  'Swing',
#  'PoleVault',
#  'GolfSwing',
#  'Lunges',
#  'PommelHorse',
#  'BreastStroke',
#  'PlayingPiano',
#  'PlayingTabla',
#  'Basketball',
#  'VolleyballSpiking',
#  'SoccerJuggling',
#  'CleanAndJerk',
#  'YoYo',
#  'PushUps',
#  'Kayaking',
#  'HulaHoop',
#  'JugglingBalls',
#  'PlayingGuitar',
#  'Fencing',
#  'ThrowDiscus',
#  'MilitaryParade',
#  'RopeClimbing',
#  'Biking',
#  'Punch',
#  'Drumming',
#  'BenchPress',
#  'Diving',
#  'SalsaSpin',
#  'PizzaTossing',
#  'TaiChi',
#  'HighJump',
#  'JavelinThrow',
#  'TrampolineJumping',
#  'Skiing',
#  'PlayingViolin',
#  'HorseRace',
#  'RockClimbingIndoor']

# %%
ucf50_preprocessing(data_dir, output_dir, class_names, number_of_frames=30)
# Out:
# Video: v_Mixing_g25_c04.avi
# Total frames: 107
# Selected frames: 94
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g25_c04.avi
# Selected frames: 11
#
# Video: v_Mixing_g13_c06.avi
# Total frames: 104
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g13_c06.avi
# Selected frames: 1
#
# Video: v_Mixing_g03_c06.avi
# Total frames: 133
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c06.avi
# Selected frames: 3
#
# Video: v_Mixing_g24_c01.avi
# Total frames: 126
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g24_c01.avi
# Video: v_Mixing_g02_c03.avi
# Total frames: 165
# Selected frames: 47
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g02_c03.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c03.avi
# Total frames: 104
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c03.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c02.avi
# Total frames: 99
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c02.avi
# Video: v_Mixing_g02_c02.avi
# Total frames: 105
# Selected frames: 32
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g02_c02.avi
# Selected frames: 1
#
# Video: v_Mixing_g03_c07.avi
# Total frames: 153
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c07.avi
# Selected frames: 1
#
# Video: v_Mixing_g03_c05.avi
# Total frames: 121
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g13_c05.avi
# Total frames: 61
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g13_c05.avi
# Selected frames: 3
#
# Video: v_Mixing_g24_c02.avi
# Total frames: 135
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g24_c02.avi
# Selected frames: 20
#
# Video: v_Mixing_g02_c01.avi
# Total frames: 103
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g02_c01.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c01.avi
# Total frames: 113
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c01.avi
# Selected frames: 2
#
# Video: v_Mixing_g24_c03.avi
# Total frames: 111
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g24_c03.avi
# Selected frames: 19
#
# Video: v_Mixing_g13_c04.avi
# Total frames: 96
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g13_c04.avi
# Selected frames: 1
#
# Video: v_Mixing_g03_c04.avi
# Total frames: 134
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c04.avi
# Video: v_Mixing_g25_c02.avi
# Total frames: 102
# Selected frames: 97
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g25_c02.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c05.avi
# Total frames: 114
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c05.avi
# Video: v_Mixing_g02_c05.avi
# Total frames: 148
# Selected frames: 50
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g02_c05.avi
# Selected frames: 0
#
# Video: .DS_Store
# Total frames: 0
# Selected frames: 0
#
# No frames to save.
# OpenCV: Couldn't read video stream from file "../data/raw/UCF50/Mixing/.DS_Store"
# Video: v_Mixing_g02_c04.avi
# Total frames: 165
# Selected frames: 54
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g02_c04.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c04.avi
# Total frames: 107
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c04.avi
# Video: v_Mixing_g25_c03.avi
# Total frames: 125
# Selected frames: 123
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g25_c03.avi
# Video: v_Mixing_g13_c01.avi
# Total frames: 111
# Selected frames: 38
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g13_c01.avi
# Selected frames: 1
#
# Video: v_Mixing_g03_c01.avi
# Total frames: 159
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c01.avi
# Selected frames: 21
#
# Video: v_Mixing_g13_c03.avi
# Total frames: 102
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g13_c03.avi
# Selected frames: 1
#
# Video: v_Mixing_g03_c03.avi
# Total frames: 135
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c03.avi
# Video: v_Mixing_g25_c01.avi
# Total frames: 116
# Selected frames: 102
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g25_c01.avi
# Video: v_Mixing_g02_c06.avi
# Total frames: 108
# Selected frames: 37
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g02_c06.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c06.avi
# Total frames: 110
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c06.avi
# Selected frames: 1
#
# Video: v_Mixing_g24_c04.avi
# Total frames: 116
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g24_c04.avi
# Selected frames: 1
#
# Video: v_Mixing_g12_c07.avi
# Total frames: 99
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g12_c07.avi
# Selected frames: 3
#
# Video: v_Mixing_g03_c02.avi
# Total frames: 128
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g03_c02.avi
# Selected frames: 18
#
# Video: v_Mixing_g13_c02.avi
# Total frames: 103
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g13_c02.avi
# Selected frames: 4
#
# Video: v_Mixing_g18_c03.avi
# Total frames: 104
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g18_c03.avi
# Selected frames: 1
#
# Video: v_Mixing_g08_c03.avi
# Total frames: 113
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g08_c03.avi
# Selected frames: 10
#
# Video: v_Mixing_g09_c06.avi
# Total frames: 101
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c06.avi
# Selected frames: 1
#
# Video: v_Mixing_g10_c05.avi
# Total frames: 118
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g10_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g10_c04.avi
# Total frames: 112
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g10_c04.avi
# Selected frames: 2
#
# Video: v_Mixing_g01_c01.avi
# Total frames: 105
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c01.avi
# Selected frames: 11
#
# Video: v_Mixing_g11_c01.avi
# Total frames: 126
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c01.avi
# Selected frames: 1
#
# Video: v_Mixing_g09_c07.avi
# Total frames: 113
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c07.avi
# Selected frames: 14
#
# Video: v_Mixing_g08_c02.avi
# Total frames: 99
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g08_c02.avi
# Selected frames: 2
#
# Video: v_Mixing_g18_c02.avi
# Total frames: 102
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g18_c02.avi
# Selected frames: 2
#
# Video: v_Mixing_g09_c05.avi
# Total frames: 97
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c03.avi
# Total frames: 142
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c03.avi
# Selected frames: 4
#
# Video: v_Mixing_g11_c03.avi
# Total frames: 128
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c03.avi
# Selected frames: 13
#
# Video: v_Mixing_g11_c02.avi
# Total frames: 119
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c02.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c02.avi
# Total frames: 126
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c02.avi
# Selected frames: 26
#
# Video: v_Mixing_g09_c04.avi
# Total frames: 136
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c04.avi
# Selected frames: 18
#
# Video: v_Mixing_g19_c04.avi
# Total frames: 101
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g19_c04.avi
# Selected frames: 29
#
# Video: v_Mixing_g18_c01.avi
# Total frames: 101
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g18_c01.avi
# Selected frames: 15
#
# Video: v_Mixing_g08_c01.avi
# Total frames: 117
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g08_c01.avi
# Selected frames: 3
#
# Video: v_Mixing_g08_c05.avi
# Total frames: 139
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g08_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c06.avi
# Total frames: 158
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c06.avi
# Selected frames: 2
#
# Video: v_Mixing_g11_c06.avi
# Total frames: 116
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c06.avi
# Selected frames: 1
#
# Video: v_Mixing_g10_c03.avi
# Total frames: 140
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g10_c03.avi
# Selected frames: 1
#
# Video: v_Mixing_g10_c02.avi
# Total frames: 121
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g10_c02.avi
# Selected frames: 10
#
# Video: v_Mixing_g11_c07.avi
# Total frames: 139
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c07.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c07.avi
# Total frames: 124
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c07.avi
# Selected frames: 1
#
# Video: v_Mixing_g09_c01.avi
# Total frames: 105
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c01.avi
# Selected frames: 6
#
# Video: v_Mixing_g19_c01.avi
# Total frames: 100
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g19_c01.avi
# Selected frames: 7
#
# Video: v_Mixing_g18_c04.avi
# Total frames: 101
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g18_c04.avi
# Selected frames: 27
#
# Video: v_Mixing_g08_c04.avi
# Total frames: 121
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g08_c04.avi
# Selected frames: 1
#
# Video: v_Mixing_g09_c03.avi
# Total frames: 125
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c03.avi
# Selected frames: 5
#
# Video: v_Mixing_g19_c03.avi
# Total frames: 102
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g19_c03.avi
# Selected frames: 1
#
# Video: v_Mixing_g14_c08.avi
# Total frames: 114
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g14_c08.avi
# Selected frames: 7
#
# Video: v_Mixing_g11_c05.avi
# Total frames: 122
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c05.avi
# Total frames: 110
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g10_c01.avi
# Total frames: 110
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g10_c01.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c04.avi
# Total frames: 121
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c04.avi
# Selected frames: 12
#
# Video: v_Mixing_g11_c04.avi
# Total frames: 140
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c04.avi
# Selected frames: 9
#
# Video: v_Mixing_g19_c02.avi
# Total frames: 106
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g19_c02.avi
# Selected frames: 1
#
# Video: v_Mixing_g09_c02.avi
# Total frames: 124
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g09_c02.avi
# Selected frames: 1
#
# Video: v_Mixing_g23_c03.avi
# Total frames: 135
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g23_c03.avi
# Video: v_Mixing_g05_c01.avi
# Total frames: 126
# Selected frames: 51
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g05_c01.avi
# Selected frames: 2
#
# Video: v_Mixing_g15_c01.avi
# Total frames: 121
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g15_c01.avi
# Selected frames: 10
#
# Video: v_Mixing_g14_c04.avi
# Total frames: 116
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g14_c04.avi
# Selected frames: 1
#
# Video: v_Mixing_g04_c04.avi
# Total frames: 109
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g04_c04.avi
# Selected frames: 4
#
# Video: v_Mixing_g11_c08.avi
# Total frames: 108
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g11_c08.avi
# Selected frames: 1
#
# Video: v_Mixing_g01_c08.avi
# Total frames: 149
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g01_c08.avi
# Selected frames: 1
#
# Video: v_Mixing_g04_c05.avi
# Total frames: 111
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g04_c05.avi
# Selected frames: 24
#
# Video: v_Mixing_g14_c05.avi
# Total frames: 103
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g14_c05.avi
# Selected frames: 1
#
# Video: v_Mixing_g23_c02.avi
# Total frames: 127
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_g23_c02.avi
# Selected frames: 1
#
# Video: v_Mixing_g15_c02.avi
# Total frames: 102
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/Mixing/v_Mixing_
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/TennisSwing/v_TennisSwing_g17_c05.avi
# Selected frames: 7
#
# Video: v_TennisSwing_g07_c05.avi
# Total frames: 173
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/TennisSwing/v_TennisSwing_g07_c05.avi
# Selected frames: 1
#
# Video: v_TennisSwing_g20_c02.avi
# Total frames: 138
# Selected frames: 30
#
# ...
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g07_c03.avi
# Total frames: 458
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g07_c03.avi
# Selected frames: 2
#
# Video: v_RockClimbingIndoor_g21_c01.avi
# Total frames: 367
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g21_c01.avi
# Selected frames: 11
#
# Video: v_RockClimbingIndoor_g06_c06.avi
# Total frames: 502
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g06_c06.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g20_c04.avi
# Total frames: 397
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g20_c04.avi
# Selected frames: 3
#
# Video: v_RockClimbingIndoor_g20_c05.avi
# Total frames: 397
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g20_c05.avi
# Selected frames: 3
#
# Video: v_RockClimbingIndoor_g06_c07.avi
# Total frames: 407
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g06_c07.avi
# Selected frames: 3
#
# Video: v_RockClimbingIndoor_g07_c02.avi
# Total frames: 443
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g07_c02.avi
# Selected frames: 17
#
# Video: v_RockClimbingIndoor_g17_c02.avi
# Total frames: 404
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g17_c02.avi
# Selected frames: 3
#
# Video: v_RockClimbingIndoor_g25_c05.avi
# Total frames: 426
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g25_c05.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g03_c07.avi
# Total frames: 412
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g03_c07.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g12_c02.avi
# Total frames: 490
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g12_c02.avi
# Selected frames: 19
#
# Video: v_RockClimbingIndoor_g02_c02.avi
# Total frames: 354
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g02_c02.avi
# Selected frames: 8
#
# Video: v_RockClimbingIndoor_g02_c03.avi
# Total frames: 300
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g02_c03.avi
# Selected frames: 2
#
# Video: v_RockClimbingIndoor_g12_c03.avi
# Total frames: 516
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g12_c03.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g24_c01.avi
# Total frames: 458
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g24_c01.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g13_c06.avi
# Total frames: 249
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g13_c06.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g03_c06.avi
# Total frames: 413
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g03_c06.avi
# Selected frames: 4
#
# Video: v_RockClimbingIndoor_g25_c04.avi
# Total frames: 414
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g25_c04.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g25_c06.avi
# Total frames: 427
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g25_c06.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g13_c04.avi
# Total frames: 224
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g13_c04.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g03_c04.avi
# Total frames: 300
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g03_c04.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g24_c03.avi
# Total frames: 397
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g24_c03.avi
# Selected frames: 24
#
# Video: v_RockClimbingIndoor_g02_c01.avi
# Total frames: 320
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g02_c01.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g12_c01.avi
# Total frames: 478
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g12_c01.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g24_c02.avi
# Total frames: 417
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g24_c02.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g03_c05.avi
# Total frames: 293
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g03_c05.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g13_c05.avi
# Total frames: 186
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g13_c05.avi
# Selected frames: 5
#
# Video: v_RockClimbingIndoor_g25_c07.avi
# Total frames: 403
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g25_c07.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g13_c01.avi
# Total frames: 167
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g13_c01.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g03_c01.avi
# Total frames: 344
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g03_c01.avi
# Selected frames: 3
#
# Video: v_RockClimbingIndoor_g25_c03.avi
# Total frames: 391
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g25_c03.avi
# Selected frames: 15
#
# Video: v_RockClimbingIndoor_g02_c04.avi
# Total frames: 290
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g02_c04.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g12_c04.avi
# Total frames: 493
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g12_c04.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g24_c06.avi
# Total frames: 408
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g24_c06.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g24_c07.avi
# Total frames: 438
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_g24_c07.avi
# Selected frames: 1
#
# Video: v_RockClimbingIndoor_g12_c05.avi
# Total frames: 491
# Selected frames: 30
#
# Video saved as ../data/processed/ORB/RockClimbingIndoor/v_RockClimbingIndoor_